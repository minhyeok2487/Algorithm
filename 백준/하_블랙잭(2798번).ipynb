# %% [markdown]
# <a href="https://colab.research.google.com/github/minhyeok2487/Algorithm/blob/main/%EB%B0%B1%EC%A4%80/%ED%95%98_%EB%B8%94%EB%9E%99%EC%9E%AD(2798%EB%B2%88).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Blackjack(N, M, data):
    result = 0
    for i in range(0, len(data)):
        for j in range(i+1, len(data)):
            for k in range(j+1, len(data)):
                sum_value = data[i] + data[j]+ data[k]
                if sum_value <= M:
                    result = max(result, sum_value)
    print(result)

N, M = list(map(int, input().split(' ')))
data = list(map(int, input().split(' ')))
Blackjack(N, M, data)
